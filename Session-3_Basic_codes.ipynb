# %%
import os

# %%
os.getcwd
# Out:
# <function nt.getcwd()>

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Sony\\Documents\\NareshIT\\Python Sessions'

# %% [markdown]
# - Session 3

# %%
pi = 3.14
r = 2
area = pi*r*r
print(area)
# Out:
# 12.56

# %%
bill_amount = 200
tip_amount = 10/100 * bill_amount
print(tip_amount)
total_amount = bill_amount + tip_amount
print(total_amount)
# Out:
# 20.0
# 220.0

# %%
salary = 20000
tax_percentage = 10/100
tax = salary * tax_percentage
print(tax)
# Out:
# 2000.0

# %%
round(9.9838)
# Out:
# 10

# %%
round(9.9838,2)
# Out:
# 9.98

# %%
round(9.98382,3)
# Out:
# 9.984
