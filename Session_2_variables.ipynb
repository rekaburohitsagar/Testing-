# %%
a =1

# %%
print(a)
# Out:
# 1

# %%
a = 1
a
# Out:
# 1

# %%
name = "rohit"
print(name)
# Out:
# rohit

# %%
name = "rohit"
last_name = "sagar"
print(name + " " + last_name)
# Out:
# rohit sagar

# %%
a = 10,20
a
# Out:
# (10, 20)

# %%
a,b = 10,20

# %%
a,b
# Out:
# (10, 20)

# %% [markdown]
# Variables:

# %%
number(one = 100
number
# Out:
#   Cell In[11], line 1
#     number(one = 100
#           ^
# SyntaxError: '(' was never closed

# %%
name = rohit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 name = rohit
#
# NameError: name 'rohit' is not defined

# %%
rohit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 rohit
#
# NameError: name 'rohit' is not defined

# %%
name = 'rohit sagar'

# %%
name
# Out:
# 'rohit sagar'

# %%
print(name)
# Out:
# rohit sagar

# %%
number = 10
Number = 20
123number = number
# Out:
#   Cell In[17], line 3
#     123number = number
#       ^
# SyntaxError: invalid decimal literal

# %%
words = [1,2,3,4,5]
print(words)
# Out:
# [1, 2, 3, 4, 5]

# %%
len(words)
# Out:
# 5

# %%
sum(words)
# Out:
# 15

# %%
min(words)
# Out:
# 1

# %% [markdown]
# - Variables can be **upper cases**
# - Variables can be **lower cases**
# - Variables are **case sensitive**
# - Variables can have **number as suffix**
# - Variables cant have **number as prefix**
# - Variables doesn't allow **spl characters**
# - Variables allow **underscore**
# - Functions are allowed as variables but shouldn't be used
# - Keywords are not allowed as variables
