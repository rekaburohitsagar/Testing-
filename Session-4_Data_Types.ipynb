# %%
n1 = 100 #integer
type(n1)
# Out:
# int

# %%
n2 = 100.23 #float
type(n2)
# Out:
# float

# %% [markdown]
# - String Data Type

# %%
city = "hyderabad"

# %%
print(city)
# Out:
# hyderabad

# %%
name = "rohit sagar"
type(name)
# Out:
# str

# %%
name = "rohit"
name
# Out:
# 'rohit'

# %% [markdown]
# name1 = "sagar"

# %%
name2 = "sagar"
name2
# Out:
# 'sagar'

# %%
print(name2)
# Out:
# sagar

# %%
len(name2)
# Out:
# 5

# %%
full_name = name + " " + name2
print(full_name)
# Out:
# rohitsagar

# %% [markdown]
# - strings can be **single quotes**
#
# - strings can be **double quotes**
#
# - strings by default considers **single quotes**
#
# - to highlight any word use $different  quotes$ in the print statement

# %% [markdown]
# # Doc string

# %%
print("""hello how are you
I'm good thank you. How about you""")
# Out:
# hello how are you
# I'm good thank you. How about you

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\Sony\\Documents\\NareshIT\\Python Sessions'

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Sony\\Documents\\NareshIT\\Python Sessions'
